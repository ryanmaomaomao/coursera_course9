# %% [markdown]
# # Report

# %% [markdown]
# ## 1 Introduction

# %% [markdown]
# I want to find the best apartment location for coffee lovers that drink coffee every work day. So the apartment location should be:
# 1. has most coffe shop in its neihborhood, and
# 2. has smallest distance of possible sets to where the poeple work, which I assume is YYZ (Toronto Pearson Airport).

# %% [markdown]
# ## 2 Data

# %% [markdown]
# 1. coffee shops in each neighborhood using search query in Foursquare.
# 2. calculation the distance between apartments in that neighborhood and YVR and find the smallest

# %%
from IPython.display import Image
PATH = "/Users/ryanchen/Desktop/projects/coursera_course9/img/"
Image(filename = PATH + "borough and neighborhood data.png", width=1000, height=1000)

# %%
from IPython.display import Image
PATH = "/Users/ryanchen/Desktop/projects/coursera_course9/img/"
Image(filename = PATH + "coffee shop location data.png", width=1000, height=1000)

# %%
from IPython.display import Image
PATH = "/Users/ryanchen/Desktop/projects/coursera_course9/img/"
Image(filename = PATH + "neighborhood location data.png", width=1000, height=1000)
